# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Insurance.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=1/3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid={'kernel':['linear', 'poly', 'rbf', 'sigmoid'],'C':[100,1000,1500,2000,2500],'gamma':['scale', 'auto']}
grid=GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(X_train,y_train)
res=grid.cv_results_
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_pred=grid.predict(X_test)
from sklearn.metrics import r2_score
r2score=r2_score(y_test,y_pred)

# %%
print("The R_score value for best parameters():",format(grid.best_params_),r2score)
# Out:
# The R_score value for best parameters(): {'C': 2500, 'gamma': 'scale', 'kernel': 'poly'} 0.8581278809859081

# %%
table=pd.DataFrame.from_dict(res)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.071677      0.007760         0.010467        0.000816     100
# 1        0.054712      0.003896         0.010069        0.000008     100
# 2        0.072003      0.004294         0.030958        0.000997     100
# 3        0.080910      0.005724         0.015277        0.003502     100
# 4        0.061945      0.003221         0.009662        0.001520     100
# 5        0.057934      0.003919         0.011283        0.003520     100
# 6        0.072421      0.009872         0.035804        0.004676     100
# 7        0.076812      0.003695         0.016087        0.004213     100
# 8        0.072826      0.003909         0.011661        0.003213    1000
# 9        0.080450      0.005814         0.012078        0.003109    1000
# 10       0.098594      0.007082         0.032604        0.003924    1000
# 11       0.086873      0.011940         0.017694        0.007470    1000
# ...

# %%
age=int(input("Enter the age:"))
bmi=float(input("Enter the bmi:"))
chil=int(input("Enter the children:"))
gender=int(input("Gender  0 or 1:"))
smoker=int(input("Smoker 0 or 1:"))
# Out:
# Enter the age: 87
# Enter the bmi: 53.264
# Enter the children: 6
# Gender  0 or 1: 1
# Smoker 0 or 1: 0

# %%
futu_predict=grid.predict([[age,bmi,chil,gender,smoker]])
futu_predict
# Out:
# array([1.42258612e+08])

# %%
import pickle
filename="Gridsearch_SVR.sav"
pickle.dump(grid,open(filename,"wb"))
load_model=pickle.load(open("Gridsearch_SVR.sav","rb"))
